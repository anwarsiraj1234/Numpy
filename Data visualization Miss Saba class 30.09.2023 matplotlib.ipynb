# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, marker = 'o')
plt.show()

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

squarey = np.array([4, 8, 1, 5])
rectanglex = np.array([2,7,0,9])
plt.plot(squarey,rectanglex, linestyle = 'dotted')
plt.xlabel("Green")
plt.ylabel("R e d")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 350])

plt.plot(x, y)

plt.xlabel("orange")
plt.ylabel("blue")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2])
y = np.array([3, 8, 1])

plt.subplot(4, 1,1)
plt.plot(x,y, color='blue')

#plot 2:
x = np.array([0, 1, 2])
y = np.array([10, 20, 30])

plt.subplot(4, 1,2)
plt.plot(x,y)
#plot 3:
x = np.array([0, 1, 2])
y = np.array([3, 8, 1])

plt.subplot(4,1,3)
plt.plot(x,y)
#plot 4:
x = np.array([0, 1, 4])
y = np.array([3, 8, 8])

plt.subplot(4,1,4)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2])
y = np.array([3, 8, 1])

plt.subplot(1, 4,1)
plt.plot(x,y, color='blue')

#plot 2:
x = np.array([0, 1, 2])
y = np.array([10, 20, 30])

plt.subplot(1, 4,2)
plt.plot(x,y)
#plot 3:
x = np.array([0, 1, 2])
y = np.array([3, 8, 1])

plt.subplot(1,4,3)
plt.plot(x,y)
#plot 4:
x = np.array([0, 1, 4])
y = np.array([3, 8, 8])

plt.subplot(1,4,4)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2])
y = np.array([3, 8, 1])

plt.subplot(3, 3,1)
plt.plot(x,y, color='blue')

#plot 2:
x = np.array([0, 1, 2])
y = np.array([10, 20, 30])

plt.subplot(3, 3,2)
plt.plot(x,y)
#plot 3:
x = np.array([0, 1, 2])
y = np.array([3, 8, 1])

plt.subplot(3,3,8)
plt.plot(x,y)
#plot 4:
x = np.array([0, 1, 4])
y = np.array([3, 8, 8])

plt.subplot(3,3,9)
plt.plot(x,y)

plt.show()

# %%
#  plt.subplot(1,3,1) (explanation)
plt.subplot(3,3,1)---->plt.subplot(rows,columns,position)
## we need to make a grid of plots

1*3=3--> capacity=3
2*3=6---->  capacity =6 
3*3=9

# %%
#plot 4:
x = np.array([0, 1, 2])
y = np.array([3, 8, 1])

plt.subplot(1, 4, 4)
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.xlabel("string")
plt.ylabel("alpha")
plt.bar(x,y)
plt.show()

# %%
pip install numpy as np
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as

# %%
x=np.array([[[1,2,3],[2,4,5],[5,6,7]],[[8,0,9],[0,6,7],[7,9,0]]]) #3 dimensional
print(x[1,1,2])
# Out:
# 7

# %%
add=[]
x=[[1,2,1],[2,1,1],[1,1,1]]
y=[[1,2,1],[2,1,1],[1,1,1]]
for i in range(0,3):
  for j in range(0,3):
    add.append(x[i][j]+y[i][j])
print(add)
# Out:
# [2, 4, 2, 4, 2, 2, 2, 2, 2]

# %%
x=np.array([[[1,2,3],[2,4,5],[5,6,7]],[[8,0,9],[0,6,7],[7,9,0]],[[11,0,9],[0,6,8],[7,9,0]]]) #3 dimensional
print(x)
# Out:
# [[[ 1  2  3]
#   [ 2  4  5]
#   [ 5  6  7]]
#
#  [[ 8  0  9]
#   [ 0  6  7]
#   [ 7  9  0]]
#
#  [[11  0  9]
#   [ 0  6  8]
#   [ 7  9  0]]]

# %%
#ist session data science class 07.10.23

import pandas as pd
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
# ...

# %%
who = pd.read_CSV("WHD.CSV")
type (who)
who.ndism

# %%
who
# Out:
# pd

# %%
who.date_reported = pd.to_datatime(who["date reproted"])    #assign date time convert

# %%
pandas.core.series.series

# %%
pd.to_datetime("Data_reported")
who.columns 
who.shape
who.country.unique()
bol = who.country == "Itally"

# %%
who[bol]

# %%
india = who[who.Country == "india"]  # chain of command

who.data_report.sort_values(ascending = False)
